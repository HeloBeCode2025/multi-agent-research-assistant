# %%
import sys
sys.path.append("..")

from config.settings import get_llm

llm = get_llm()
response = llm.invoke("Give me an Emily Dickinson quote.")
print(response.content)
# Out:
# Here's one of her most famous quotes:
#
# "Hope is the Thing with Feathers"
#
# (From poem 254, "Hope is the Thing with Feathers...")
