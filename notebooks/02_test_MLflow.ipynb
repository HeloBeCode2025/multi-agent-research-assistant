# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///../mlflow.db")
mlflow.set_experiment("test-setup")
with mlflow.start_run():
    mlflow.log_param("provider", "ollama")
    mlflow.log_param("model", "llama3.1:8b")
    mlflow.log_metric("test_score", 0.95)
    mlflow.log_metric("latency_ms", 1200)

print(mlflow.get_tracking_uri())
# Out:
# /Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/tracking/_tracking_service/utils.py:184: FutureWarning: The filesystem tracking backend (e.g., './mlruns') is deprecated as of February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://mlflow.org/docs/latest/self-hosting/migrate-from-file-store for migration guidance.
#   return FileStore(store_uri, store_uri)
# WARNING:root:Malformed experiment 'app'. Detailed error Yaml file '../../multi-agent-research-assistant/app/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py", line 383, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py", line 481, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py", line 1670, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py", line 1663, in _read_helper
#     result = read_yaml(root, file_name)
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/utils/yaml_utils.py", line 104, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file '../../multi-agent-research-assistant/app/meta.yaml' does not exist.
# WARNING:root:Malformed experiment 'config'. Detailed error Yaml file '../../multi-agent-research-assistant/config/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py", line 383, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py", line 481, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py", line 1670, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py", line 1663, in _read_helper
#     result = read_yaml(root, file_name)
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/utils/yaml_utils.py", line 104, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file '../../multi-agent-research-assistant/config/meta.yaml' does not exist.
# WARNING:root:Malformed experiment 'tests'. Detailed error Yaml file '../../multi-agent-research-assistant/tests/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py", line 383, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py", line 481, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py", line 1670, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py", line 1663, in _read_helper
#     result = read_yaml(root, file_name)
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/utils/yaml_utils.py", line 104, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file '../../multi-agent-research-assistant/tests/meta.yaml' does not exist.
# WARNING:root:Malformed experiment 'agents'. Detailed error Yaml file '../../multi-agent-research-assistant/agents/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py", line 383, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py", line 481, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py", line 1670, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py", line 1663, in _read_helper
#     result = read_yaml(root, file_name)
#   File "/Users/hbic/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/utils/yaml_utils.py", line 104, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file '../../multi-agent-research-assistant/agents/meta.yaml' does not exist.
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[7], line 4
#       1 import mlflow
#       2
#       3 mlflow.set_tracking_uri("../../multi-agent-research-assistant")
# ----> 4 mlflow.set_experiment("test-setup")
#       5 with mlflow.start_run():
#       6     mlflow.log_param("provider", "ollama")
#       7     mlflow.log_param("model", "llama3.1:8b")
#
# File ~/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/tracking/fluent.py:194, in set_experiment(experiment_name, experiment_id)
#     192 with _experiment_lock:
#     193     if experiment_id is None:
# --> 194         experiment = client.get_experiment_by_name(experiment_name)
#     195         if not experiment:
#     196             _logger.info(
#     197                 "Experiment with name '%s' does not exist. Creating a new experiment.",
#     198                 experiment_name,
#     199             )
#
# File ~/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/tracking/_tracking_service/client.py:283, in TrackingServiceClient.get_experiment_by_name(self, name)
#     275 def get_experiment_by_name(self, name):
#     276     """
#     277     Args:
#     278         name: The experiment name.
#    (...)    281         :py:class:`mlflow.entities.Experiment`
#     282     """
# --> 283     return self.store.get_experiment_by_name(name)
#
# File ~/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py:409, in FileStore.get_experiment_by_name(self, experiment_name)
#     401 def pagination_wrapper_func(number_to_get, next_page_token):
#     402     return self.search_experiments(
#     403         view_type=ViewType.ALL,
#     404         max_results=number_to_get,
#     405         filter_string=f"name = '{experiment_name}'",
#     406         page_token=next_page_token,
#     407     )
# --> 409 experiments = get_results_from_paginated_fn(
#     410     paginated_fn=pagination_wrapper_func,
#     411     max_results_per_page=SEARCH_MAX_RESULTS_THRESHOLD,
#     412     max_results=None,
#     413 )
#     414 return experiments[0] if len(experiments) > 0 else None
#
# File ~/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/utils/__init__.py:255, in get_results_from_paginated_fn(paginated_fn, max_results_per_page, max_results)
#     253     page_results = paginated_fn(num_to_get, next_page_token)
#     254 else:
# --> 255     page_results = paginated_fn(max_results_per_page, next_page_token)
#     256 all_results.extend(page_results)
#     257 if hasattr(page_results, "token") and page_results.token:
#
# File ~/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py:402, in FileStore.get_experiment_by_name.<locals>.pagination_wrapper_func(number_to_get, next_page_token)
#     401 def pagination_wrapper_func(number_to_get, next_page_token):
# --> 402     return self.search_experiments(
#     403         view_type=ViewType.ALL,
#     404         max_results=number_to_get,
#     405         filter_string=f"name = '{experiment_name}'",
#     406         page_token=next_page_token,
#     407     )
#
# File ~/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py:383, in FileStore.search_experiments(self, view_type, max_results, filter_string, order_by, page_token)
#     380 for exp_id in experiment_ids:
#     381     try:
#     382         # trap and warn known issues, will raise unexpected exceptions to caller
# --> 383         exp = self._get_experiment(exp_id, view_type)
#     384         if exp is not None:
#     385             experiments.append(exp)
#
# File ~/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/store/tracking/file_store.py:474, in FileStore._get_experiment(self, experiment_id, view_type)
#     472 def _get_experiment(self, experiment_id, view_type=ViewType.ALL):
#     473     self._check_root_dir()
# --> 474     _validate_experiment_id(experiment_id)
#     475     experiment_dir = self._get_experiment_path(experiment_id, view_type)
#     476     if experiment_dir is None:
#
# File ~/Desktop/Octocat/multi-agent-research-assistant/.venv/lib/python3.14/site-packages/mlflow/utils/validation.py:403, in _validate_experiment_id(exp_id)
#     401 """Check that `experiment_id`is a valid string or None, raise an exception if it isn't."""
#     402 if exp_id is not None and _EXPERIMENT_ID_REGEX.match(exp_id) is None:
# --> 403     raise MlflowException(
#     404         f"Invalid experiment ID: '{exp_id}'", error_code=INVALID_PARAMETER_VALUE
#     405     )
#
# MlflowException: Invalid experiment ID: '.venv'
